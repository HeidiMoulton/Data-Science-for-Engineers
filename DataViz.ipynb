# %% [markdown]
# # **Module 2: Data Visualization**
# Well made graphics can greatly increase our ability to understand and interpret data.
# In this module we will use the matplotlib to generate a variety of basic graphs.

# %%
# Import Packages 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read in the data we generated in the last exercise 
df = pd.read_csv("weatherCondensed.csv")
df.head()
# Out:
#    Unnamed: 0             Formatted Date        Summary Precip Type  Humidity  \
# 0           0  2006-01-01 12:00:00+01:00  Mostly Cloudy        rain      0.77
# 1           1  2006-01-02 12:00:00+01:00       Overcast        rain      0.80
# 2           2  2006-01-03 12:00:00+01:00  Mostly Cloudy        rain      0.89
# 3           3  2006-01-04 12:00:00+01:00       Overcast        rain      0.89
# 4           4  2006-01-05 12:00:00+01:00       Overcast        rain      0.92
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0            21.4452                   149.0          11.2056
# 1            13.1859                   156.0          11.2700
# 2             9.0643                   257.0          11.1251
# 3            15.8263                    20.0          11.1251
# 4             8.0822                    22.0           4.6690
#
#    Pressure (millibars)                      Daily Summary  Temperature (F)  \
# 0               1012.00  Mostly cloudy throughout the day.            40.84
# 1               1008.37       Overcast throughout the day.            44.59
# 2               1020.80  Mostly cloudy throughout the day.            37.13
# 3               1025.36       Overcast throughout the day.            37.00
# 4               1020.77              Foggy in the morning.            38.92
#
#    Apparent Temperature (F) Wind Type
# 0                     33.45     still
# 1                     40.09     still
# 2                     32.60     still
# 3                     30.00     still
# 4                     35.19     still

# %% [markdown]
# ## Matplotlib Basics
# The matplotlip.pyplot library is a collection functions made to mimic MATLAB's graphing capabilities.
#
# The basic structure for creating a graphic using Matplolib is as follows:
# * **Initiate your graphic**: Specify the type of graph by using a function such as plt.scatter() or plt.hist() and input your data
#
# * **Add Additional Elements**: Use further commands such as plt.xlabel() to add labels or additional formatting
#
# * **Show your Graphic**: Use the plt.show() function to display your graphic

# %%
#### Initiate Graphic #####
# x and y must be of the same size. If only one argument is given it will be plotted as the y variable
# plt.plot() is the most basic graph command and by default forms a line graph 
plt.plot(df.index, df["Temperature (F)"]) 
#### Show Graphic ####
plt.show()

# %% [markdown]
# ### Adding Chart and Axis Labels
# To improve our graph, we have it display only one year of data and add axis titles.

# %%
#### Initiate Graphic #####
plt.plot(df.index[0:365], df["Temperature (F)"][0:365]) 
#### Add Additional Elements ####
plt.xlabel("Days")
plt.ylabel("Degrees (F)")
plt.title("Daily Temperature at Noon")
#### Show Graphic ####
plt.show()

# %% [markdown]
# ### Specifying Axis Limits and Tick Marks
# We can also modify the axis limits and frequency of tick marks

# %%
#### Initiate Graphic #####
plt.plot(df.index[0:365], df["Temperature (F)"][0:365]) 
#### Add Additional Elements ####
plt.xlabel("Months")
plt.ylabel("Degrees (F)")
plt.title("Daily Temperature at Noon (2006)")
plt.ylim([0,100])
plt.yticks(range(0,100,5))  # yticks() can take in any list.
plt.xticks([0,31,59,90,120,151,181,212,243,273,304,334],
           ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov","Dec"])
plt.grid()  # adds background gird 
#### Show Graphic ####
plt.show()

# %% [markdown]
# ### Graphing more than one variable at once
# There are a few ways to plot multiple lines at once, but the most simple is to initiate the second line of data by repeating the plt.plot() function.
#
# Here we have added added two additional arguments to the plt.plot() functions.
# * "b-" indicated that the data should be drawn as a blue line, and "r-" indicated a red line.
# * **label** assigned a name to each data series
#
# We also added the plt.legend() to display our data labels.

# %%
#### Initiate Graphic #####
plt.plot(df.index[0:365], df["Temperature (F)"][0:365], "b-", label = "Measured Temperature" ) 
plt.plot(df.index[0:365], df["Apparent Temperature (F)"][0:365], "r-", label = "Apparent Temperature")
#### Add Additional Elements ####
plt.xlabel("Days")
plt.xlabel("Months")
plt.ylabel("Degrees (F)")
plt.title("Daily Temperature at Noon (2006)")
plt.ylim([0,100])
plt.yticks(range(0,100,5)) 
plt.xticks([0,31,59,90,120,151,181,212,243,273,304,334],
           ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov","Dec"])
plt.grid()  
plt.legend() # adds legend
#### Show Graphic ####
plt.show()

# %% [markdown]
# ## Scatter Plots
# Scatter plots can be formed by adapting the plt.plot() function or by using plt.scatter().
#
# First I will create a scatter plot by adding the argument "ro" to the plt.plot() command. This specifies red circles.
# I could also use "y^" for yellow triangles or "gs" for green squares.

# %%
# I want to form a scatter plot of the daily difference between measured and apparent temperature. 
# Again I will just look at the first year of data 
temp_diff = df["Temperature (F)"][0:365] - df["Apparent Temperature (F)"][0:365]

#### Initiate Graphic #####
plt.plot(temp_diff, "ro")     # We don't specify x values so it automatically assigns a range from 0 to 364
#### Add Additional Elements ####
plt.xlabel("Days")
plt.ylabel("Degrees (F)")
plt.title("Difference Between Measured and Apparent Temperature")
plt.xticks([0,31,59,90,120,151,181,212,243,273,304,334],
           ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov","Dec"])
#### Show Graphic ####
plt.show()

# %% [markdown]
# I can recreate this same graph using plt.scatter(). It defaults to using blue circles as the markers.

# %%
#### Initiate Graphic #####
plt.scatter(range(365),temp_diff)     # scatter requires that we specify both the x and y data 
#### Add Additional Elements ####
plt.xlabel("Days")
plt.ylabel("Degrees (F)")
plt.title("Difference Between Measured and Apparent Temperature")
plt.xticks([0,31,59,90,120,151,181,212,243,273,304,334],
           ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov","Dec"])
#### Show Graphic ####
plt.show()

# %% [markdown]
# I want to see if there is a relationship between the difference in measured and apparent temperature and the wind speed, so I plot one as a function of the other.

# %%
#### Initiate Graphic #####
plt.scatter(df["Wind Speed (km/h)"][0:365],temp_diff, color = "green", marker = "^")     # here I also change the marker shape and color  
#### Add Additional Elements ####
plt.xlabel("Wind Speed in km/h")
plt.ylabel("Difference in Degrees (F)")
#### Show Graphic ####
plt.show()

# %% [markdown]
# ## Histograms
# Histograms can be made using the plt.hist() function. It requires the user to input the data followed by the number of bins.

# %%
#### Initiate Graphic #####
plt.hist(df["Wind Speed (km/h)"])   #No bins specified, default used
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.title("Distribution of Wind Speed")
#### Show Graphic ####
plt.show()

# %% [markdown]
# Previously we created a column named "Wind Type" based on whether the summary contained the words "breezy" or "windy."
#
# Now we want to make histograms of the Wind Speed based on Wind Type to explore how "windy" and "breezy" were defined.

# %%
df_windy, df_breezy, df_still = df[df["Wind Type"]== "windy"],df[df["Wind Type"]== "breezy"],df[df["Wind Type"]== "still"]

#### Initiate Graphic #####
plt.hist(df_still["Wind Speed (km/h)"])
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.title("Distribution of Still Wind Speed")
#### Show Graphic ####
plt.show()

#### Initiate Graphic #####
plt.hist(df_breezy["Wind Speed (km/h)"])
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.title("Distribution of Breezy Wind Speed")
#### Show Graphic ####
plt.show()

#### Initiate Graphic #####
plt.hist(df_windy["Wind Speed (km/h)"])
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.title("Distribution of Windy Wind Speed")
#### Show Graphic ####
plt.show()

# %% [markdown]
# ### Printing Multiple Plots at Once
#
# The histograms above are interesting, but they would be easier to compare if they had the same x axis limits and wre listed side by side.
#
# We will use plt.subplot to do this. It called before you initiate your plots and its arguments are as follows:
#
# plt.subplot(number of rows, number of columns, number of plot you are currently on)
#
# Note that we don't call plt.show() until the end

# %%
#### Subplot Info #####
plt.subplot(1,3,1)
#### Initiate Graphic #####
plt.hist(df_still["Wind Speed (km/h)"], bins = range(0,65,5) )
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.xlim(0,60)
plt.xticks(range(0,70,10))
plt.title("Still")


#### Subplot Info #####
plt.subplot(1,3,2)
#### Initiate Graphic #####
plt.hist(df_breezy["Wind Speed (km/h)"], bins = range(0,65,5) )
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.xlim(0,60)
plt.xticks(range(0,70,10))
plt.title("Breezy")


#### Subplot Info #####
plt.subplot(1,3,3)
#### Initiate Graphic #####
plt.hist(df_windy["Wind Speed (km/h)"], bins = range(0,65,5) )
#### Add Additional Elements ####
plt.ylabel("Occurrences")
plt.xlabel("Wind Speed (km/h)")
plt.xlim(0,60)
plt.xticks(range(0,70,10))
plt.title("Windy")

#### Show Graphic ####
plt.tight_layout()  #Helps Prevent Graphs from overlapping 
plt.show()
